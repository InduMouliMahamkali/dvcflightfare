# %%
import os
import pandas as pd

# %%
df=pd.read_csv("../original_data/data_original.csv")

# %%
df
# Out:
#        Total_Stops  Price  journey_day  journey_month  Dep_Time_hour  \
# 0                0   3897           24              3             22
# 1                2   7662            5              1              5
# 2                2  13882            6              9              9
# 3                1   6218            5             12             18
# 4                1  13302            3              1             16
# ...            ...    ...          ...            ...            ...
# 10677            0   4107            4              9             19
# 10678            0   4145           27              4             20
# 10679            0   7229           27              4              8
# 10680            0  12648            3              1             11
# 10681            2  11753            5              9             10
#
#        Dep_Time_min  Arrival_Time_hour  Arrival_Time_min  Duration_hours  \
# ...

# %%
a=df.describe()

# %%
a.loc[["min","max"]].to_json("schema_in.json")

# %%
class OutofRange(Exception):
    def __init__(self, message="input not in range"):
        self.input_=input_
        self.message=message
        super()
